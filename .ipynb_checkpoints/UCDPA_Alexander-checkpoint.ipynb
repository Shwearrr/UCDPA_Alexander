# %%
#Importing Librarys

# Import NumPy for numerical computing
import numpy as np

# Import Pandas for DataFrames
import pandas as pd

# Import Matplotlib for visulization
from matplotlib import pyplot as plt

# Import Seaborn for easier visulization
import seaborn as sns

# %%
# Import the data from csv file saved locally
GOT = pd.read_csv('screentime.csv')

# %%
#size of the dataframe
GOT.shape
# Out:
# (191, 6)

# %%
#What is the type of data that is in the columns
GOT.dtypes
# Out:
# index            int64
# name            object
# imdbUrl         object
# screentime     float64
# episodes        object
# portrayedBy     object
# dtype: object

# %%
#Visualize what we are workng with
GOT.head()
# Out:
#    index                name                                   imdbUrl  \
# 0      0    Tyrion Lannister  http://www.imdb.com/character/ch0146096/
# 1      1            Jon Snow  http://www.imdb.com/character/ch0155777/
# 2      2  Daenerys Targaryen  http://www.imdb.com/character/ch0158597/
# 3      3    Cersei Lannister  http://www.imdb.com/character/ch0159526/
# 4      4         Sansa Stark  http://www.imdb.com/character/ch0158137/
#
#    screentime episodes                                        portrayedBy
# 0      293.30       54  {'name': 'Peter Dinklage', 'imdbUrl': 'http://...
# 1      268.15       49  {'name': 'Kit Harington', 'imdbUrl': 'http://w...
# 2      221.30       49  {'name': 'Emilia Clarke', 'imdbUrl': 'http://w...
# 3      201.45       52  {'name': 'Lena Headey', 'imdbUrl': 'http://www...
# 4      199.30       47  {'name': 'Sophie Turner', 'imdbUrl': 'http://w...
